# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,a,b,c):
    return a*x**2 + b*x +c

# %%
xlist = np.linspace(-10,10,num=1000)
ylist = f(xlist,3,1,4)

# %% [markdown]
# Now do some plotting

# %%
plt.figure(num=0,dpi=120) 
plt.plot(xlist,ylist,label="f(x)")
plt.plot(zlist,ylist**(1/2), label="f(x)**(1/2")
plt.title("Plo
